# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
# Importing the SimpleImputer class
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder

# %%
dataset = pd.read_csv('/content/gdrive/My Drive/CBD_Assignment 1/News_Final.csv')
enc = OrdinalEncoder()
dataset[["Topic"]] = enc.fit_transform(dataset[["Topic"]])
dataset
# Out:
#          IDLink                                              Title  \
# 0           1.0                      On The Economy, Give Obama AD
# 1           2.0  To one CEO, 'Janet Yellen's Magic Money Machin...
# 2           3.0   3 Ways to Jumpstart a Community-Grounded Economy
# 3           4.0  Despite China Slowdown, Global Economy Expecte...
# 4           5.0                       New Economy Week Starts Here
# ...         ...                                                ...
# 93234  104798.0  Obama administration proposes new rules for K-...
# 93235  104799.0        Tournoi de foot solidaire pour la Palestine
# 93236  104800.0  Car, truck and motorcycle enthusiasts will gat...
# 93237  104801.0  Obama heads to Europe amid British referendum'...
# 93238  104802.0       Obama leaves for NATO summit, visit to Spain
#
#                                                 Headline  \
# 0      Hillary Clinton got the laugh line of the week...
# 1      """I believe something is shifting in the unde...
# 2      This article is part of New Economy Week, a co...
# 3      Global trade and economic activity--held back ...
# 4      New Economy Week Starts Here. This week, we br...
# ...                                                  ...
# 93234  But it almost certainly won't be the Obama adm...
# 93235  Dans le cadre de la campagne annuelle de solid...
# 93236  Car, truck and motorcycle enthusiasts will gat...
# 93237  President Barack Obama is slated to embark on ...
# 93238  President Barack Obama left Thursday to take p...
#
#                                     Source  Topic       PublishDate  \
# 0                                   Forbes    0.0  2015-11-09 22:40
# 1                              MarketWatch    0.0  2015-11-09 22:40
# 2                            YES! Magazine    0.0   2015-11-09 9:40
# 3             International Business Times    0.0  2015-11-09 11:40
# 4                            YES! Magazine    0.0   2015-11-09 9:40
# ...                                    ...    ...               ...
# 93234                      Washington Post    2.0  2016-07-06 23:20
# 93235                           L'Humanité    3.0  2016-07-07 15:20
# 93236               Palestine Herald Press    3.0   2016-07-06 0:00
# 93237  Associated Press via Yahoo! Finance    2.0   2016-07-07 8:30
# 93238                  AFP via Yahoo! News    2.0   2016-07-07 8:28
#
#        SentimentTitle  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0            0.087462          -0.093750        13           1         2
# 1            0.037689          -0.177667        42           0         0
# 2           -0.094491          -0.060817        98          23         0
# 3            0.077340          -0.079204         7           1        10
# 4           -0.065219          -0.145935        34           0         0
# ...               ...                ...       ...         ...       ...
# 93234        0.036828          -0.109109        33           3         1
# 93235       -0.047246          -0.106600         4           0         0
# 93236        0.000000           0.104257         1           0         0
# 93237        0.000000           0.013700         0           0         0
# 93238       -0.099437           0.118648         0           0         0
#
# [93239 rows x 11 columns]

# %%
imputer = SimpleImputer(missing_values = np.nan,strategy ='mean')
imputer = imputer.fit(dataset[["Topic","SentimentTitle","SentimentHeadline"]])
 
# Imputing the data    
dataset[["Topic","SentimentTitle","SentimentHeadline"]] = imputer.transform(dataset[["Topic","SentimentTitle","SentimentHeadline"]])
dataset
# Out:
#          IDLink                                              Title  \
# 0           1.0                      On The Economy, Give Obama AD
# 1           2.0  To one CEO, 'Janet Yellen's Magic Money Machin...
# 2           3.0   3 Ways to Jumpstart a Community-Grounded Economy
# 3           4.0  Despite China Slowdown, Global Economy Expecte...
# 4           5.0                       New Economy Week Starts Here
# ...         ...                                                ...
# 93234  104798.0  Obama administration proposes new rules for K-...
# 93235  104799.0        Tournoi de foot solidaire pour la Palestine
# 93236  104800.0  Car, truck and motorcycle enthusiasts will gat...
# 93237  104801.0  Obama heads to Europe amid British referendum'...
# 93238  104802.0       Obama leaves for NATO summit, visit to Spain
#
#                                                 Headline  \
# 0      Hillary Clinton got the laugh line of the week...
# 1      """I believe something is shifting in the unde...
# 2      This article is part of New Economy Week, a co...
# 3      Global trade and economic activity--held back ...
# 4      New Economy Week Starts Here. This week, we br...
# ...                                                  ...
# 93234  But it almost certainly won't be the Obama adm...
# 93235  Dans le cadre de la campagne annuelle de solid...
# 93236  Car, truck and motorcycle enthusiasts will gat...
# 93237  President Barack Obama is slated to embark on ...
# 93238  President Barack Obama left Thursday to take p...
#
#                                     Source  Topic       PublishDate  \
# 0                                   Forbes    0.0  2015-11-09 22:40
# 1                              MarketWatch    0.0  2015-11-09 22:40
# 2                            YES! Magazine    0.0   2015-11-09 9:40
# 3             International Business Times    0.0  2015-11-09 11:40
# 4                            YES! Magazine    0.0   2015-11-09 9:40
# ...                                    ...    ...               ...
# 93234                      Washington Post    2.0  2016-07-06 23:20
# 93235                           L'Humanité    3.0  2016-07-07 15:20
# 93236               Palestine Herald Press    3.0   2016-07-06 0:00
# 93237  Associated Press via Yahoo! Finance    2.0   2016-07-07 8:30
# 93238                  AFP via Yahoo! News    2.0   2016-07-07 8:28
#
#        SentimentTitle  SentimentHeadline  Facebook  GooglePlus  LinkedIn
# 0            0.087462          -0.093750        13           1         2
# 1            0.037689          -0.177667        42           0         0
# 2           -0.094491          -0.060817        98          23         0
# 3            0.077340          -0.079204         7           1        10
# 4           -0.065219          -0.145935        34           0         0
# ...               ...                ...       ...         ...       ...
# 93234        0.036828          -0.109109        33           3         1
# 93235       -0.047246          -0.106600         4           0         0
# 93236        0.000000           0.104257         1           0         0
# 93237        0.000000           0.013700         0           0         0
# 93238       -0.099437           0.118648         0           0         0
#
# [93239 rows x 11 columns]

# %% [markdown]
#  Random Forest working- https://towardsdatascience.com/an-implementation-and-explanation-of-the-random-forest-in-python-77bf308a9b76

# %%
# Gives the names of the columns/features
print(dataset.keys())
# Out:
# Index(['IDLink', 'Title', 'Headline', 'Source', 'Topic', 'PublishDate',
#        'SentimentTitle', 'SentimentHeadline', 'Facebook', 'GooglePlus',
#        'LinkedIn'],
#       dtype='object')

# %% [markdown]
# Data Exploration and cleaning
# https://towardsdatascience.com/a-complete-machine-learning-walk-through-in-python-part-one-c62152f39420

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93239 entries, 0 to 93238
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IDLink             93239 non-null  float64
#  1   Title              93239 non-null  object
#  2   Headline           93224 non-null  object
#  3   Source             92960 non-null  object
#  4   Topic              93239 non-null  float64
#  5   PublishDate        93239 non-null  object
#  6   SentimentTitle     93239 non-null  float64
#  7   SentimentHeadline  93239 non-null  float64
#  8   Facebook           93239 non-null  int64
#  9   GooglePlus         93239 non-null  int64
#  10  LinkedIn           93239 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 7.8+ MB

# %%
dataset.isnull().sum(axis = 0)
# Out:
# IDLink                 0
# Title                  0
# Headline              15
# Source               279
# Topic                  0
# PublishDate            0
# SentimentTitle         0
# SentimentHeadline      0
# Facebook               0
# GooglePlus             0
# LinkedIn               0
# dtype: int64

# %%
dataset = dataset.drop(columns = ['Headline', 'Source'])
#df.drop(columns=['B', 'C'])
dataset.head()
# Out:
#    IDLink                                              Title  Topic  \
# 0     1.0                      On The Economy, Give Obama AD    0.0
# 1     2.0  To one CEO, 'Janet Yellen's Magic Money Machin...    0.0
# 2     3.0   3 Ways to Jumpstart a Community-Grounded Economy    0.0
# 3     4.0  Despite China Slowdown, Global Economy Expecte...    0.0
# 4     5.0                       New Economy Week Starts Here    0.0
#
#         PublishDate  SentimentTitle  SentimentHeadline  Facebook  GooglePlus  \
# 0  2015-11-09 22:40        0.087462          -0.093750        13           1
# 1  2015-11-09 22:40        0.037689          -0.177667        42           0
# 2   2015-11-09 9:40       -0.094491          -0.060817        98          23
# 3  2015-11-09 11:40        0.077340          -0.079204         7           1
# 4   2015-11-09 9:40       -0.065219          -0.145935        34           0
#
#    LinkedIn
# 0         2
# 1         0
# 2         0
# 3        10
# 4         0

# %% [markdown]
# drop columns= https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
# Calculate first and third quartile
first_quartile = dataset['SentimentTitle'].describe()['25%']
third_quartile = dataset['SentimentTitle'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
dataset = dataset[(dataset['SentimentTitle'] > (first_quartile - 3 * iqr)) &
            (dataset['SentimentTitle'] < (third_quartile + 3 * iqr))]

# %%
# Matplotlib visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# Set default font size
plt.rcParams['font.size'] = 24
#figsize(8, 8)
f = plt.figure(figsize=(8,8))
plt.hist(dataset['SentimentTitle'].dropna(), bins = 20, edgecolor = 'black');
plt.xlabel('SentimentTitle'); 
plt.ylabel('Count'); plt.title('SentimentTitle');  #Single Variable plots

# %%
# Calculate first and third quartile
first_quartile = dataset['SentimentHeadline'].describe()['25%']
third_quartile = dataset['SentimentHeadline'].describe()['75%']

# Interquartile range
iqr = third_quartile - first_quartile

# Remove outliers
dataset = dataset[(dataset['SentimentHeadline'] > (first_quartile - 3 * iqr)) &
            (dataset['SentimentHeadline'] < (third_quartile + 3 * iqr))]

# %%
f = plt.figure(figsize=(8,8))
plt.hist(dataset['SentimentHeadline'].dropna(), bins = 100, edgecolor = 'black');
plt.xlabel('SentimentHeadline'); 
plt.ylabel('Count'); plt.title('SentimentHeadline');  # Single Variable Plots

# %%
# Find all correlations with the Tooic and sort 
correlations_data = dataset.corr()['Topic'].sort_values()
# Print the most negative correlations
print(correlations_data.head(15), '\n')

# Print the most positive correlations
print(correlations_data.tail(15))
# Out:
# LinkedIn            -0.035134
# SentimentTitle       0.001230
# SentimentHeadline    0.029602
# GooglePlus           0.067718
# Facebook             0.105241
# IDLink               0.748682
# Topic                1.000000
# Name: Topic, dtype: float64
#
# LinkedIn            -0.035134
# SentimentTitle       0.001230
# SentimentHeadline    0.029602
# GooglePlus           0.067718
# Facebook             0.105241
# IDLink               0.748682
# Topic                1.000000
# Name: Topic, dtype: float64

# %%
# Find all correlations with the score and sort 
correlations_data = dataset.corr()['SentimentTitle'].sort_values()
# Print the most negative correlations
print(correlations_data.head(15), '\n')

# Print the most positive correlations
print(correlations_data.tail(15))
# Out:
# GooglePlus          -0.009839
# Facebook            -0.003591
# Topic                0.001230
# IDLink               0.003087
# LinkedIn             0.003751
# SentimentHeadline    0.182238
# SentimentTitle       1.000000
# Name: SentimentTitle, dtype: float64
#
# GooglePlus          -0.009839
# Facebook            -0.003591
# Topic                0.001230
# IDLink               0.003087
# LinkedIn             0.003751
# SentimentHeadline    0.182238
# SentimentTitle       1.000000
# Name: SentimentTitle, dtype: float64

# %%
# Find all correlations with the score and sort 
correlations_data = dataset.corr()['SentimentHeadline'].sort_values()
# Print the most negative correlations
print(correlations_data.head(15), '\n')

# Print the most positive correlations
print(correlations_data.tail(15))
# Out:
# Facebook             0.000462
# GooglePlus           0.001913
# LinkedIn             0.006078
# IDLink               0.024842
# Topic                0.029602
# SentimentTitle       0.182238
# SentimentHeadline    1.000000
# Name: SentimentHeadline, dtype: float64
#
# Facebook             0.000462
# GooglePlus           0.001913
# LinkedIn             0.006078
# IDLink               0.024842
# Topic                0.029602
# SentimentTitle       0.182238
# SentimentHeadline    1.000000
# Name: SentimentHeadline, dtype: float64

# %%
# Seaborn for visualization
import seaborn as sns
sns.set(font_scale = 2)

# Extract the columns to  plot
plot_data = dataset[['Topic', 'SentimentTitle', 
                      'SentimentHeadline', 
                      'Facebook', 'GooglePlus','LinkedIn']]


# Function to calculate correlation coefficient between two columns
def corr_func(x, y, **kwargs):
    r = np.corrcoef(x, y)
    print(r)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.2, .8), xycoords=ax.transAxes,
                size = 20)

# Create the pairgrid object
grid = sns.PairGrid(data = plot_data, size = 3)

# Upper is a scatter plot
grid.map_upper(plt.scatter, color = 'red', alpha = 0.6)

# Diagonal is a histogram
grid.map_diag(plt.hist, color = 'red', edgecolor = 'black')

# Bottom is correlation and density plot
grid.map_lower(corr_func(dataset.iloc[:,4],dataset.iloc[:,5]));
grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)

# Title for entire plot
plt.suptitle('Pairs Plot of Energy Data', size = 36, y = 1.02);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1209: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))
# [1.         0.18223833]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-70bc7171cb65> in <module>()
#      28
#      29 # Bottom is correlation and density plot
# ---> 30 grid.map_lower(corr_func(dataset.iloc[:,4],dataset.iloc[:,5]));
#      31 grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)
#      32
#
# <ipython-input-26-70bc7171cb65> in corr_func(x, y, **kwargs)
#      14     print(r[0])
#      15     ax = plt.gca()
# ---> 16     ax.annotate("r = {:.2f}".format(r[0]),
#      17                 xy=(.2, .8), xycoords=ax.transAxes,
#      18                 size = 20)
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %%
# Extract the columns to  plot
plot_data = dataset[['Topic', 'SentimentTitle', 
                      'SentimentHeadline', 
                      'Facebook', 'GooglePlus','LinkedIn']]


# Function to calculate correlation coefficient between two columns
def corr_func(x, y, **kwargs):
    r = np.corrcoef(x, y)
    ax = plt.gca()
    ax.annotate(list(map("r = {:.2f}".format(r))),
                xy=(.2, .8), xycoords=ax.transAxes,
                size = 20)

# Create the pairgrid object
grid = sns.PairGrid(data = plot_data, size = 3)

# Upper is a scatter plot
grid.map_upper(plt.scatter, color = 'red', alpha = 0.6)

# Diagonal is a histogram
grid.map_diag(plt.hist, color = 'red', edgecolor = 'black')

# Bottom is correlation and density plot
grid.map_lower(corr_func(dataset.iloc[:,4],dataset.iloc[:,5]));
grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)

# Title for entire plot
plt.suptitle('Pairs Plot of Energy Data', height = 36, y = 1.02);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1209: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ec4fe46c1155> in <module>()
#      23
#      24 # Bottom is correlation and density plot
# ---> 25 grid.map_lower(corr_func(dataset.iloc[:,4],dataset.iloc[:,5]));
#      26 grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)
#      27
#
# <ipython-input-30-ec4fe46c1155> in corr_func(x, y, **kwargs)
#       9     r = np.corrcoef(x, y)
#      10     ax = plt.gca()
# ---> 11     ax.annotate(list(map("r = {:.2f}".format(r))),
#      12                 xy=(.2, .8), xycoords=ax.transAxes,
#      13                 size = 20)
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %%
# Extract the columns to  plot
plot_data = dataset[['Topic', 'SentimentTitle', 
                      'SentimentHeadline']]


# Function to calculate correlation coefficient between two columns
def corr_func(x, y, **kwargs):
    r = np.corrcoef(x, y)[2][4][5]
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.2, .8), xycoords=ax.transAxes,
                size = 20)

# Create the pairgrid object
grid = sns.PairGrid(data = plot_data, size = 3)

# Upper is a scatter plot
grid.map_upper(plt.scatter, color = 'red', alpha = 0.6)

# Diagonal is a histogram
grid.map_diag(plt.hist, color = 'red', edgecolor = 'black')

# Bottom is correlation and density plot
grid.map_lower(corr_func);
grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)

# Title for entire plot
plt.suptitle('Pairs Plot of Energy Data', height = 36, y = 1.02);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1209: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-3a1809577e82> in <module>()
#      22
#      23 # Bottom is correlation and density plot
# ---> 24 grid.map_lower(corr_func);
#      25 grid.map_lower(sns.kdeplot, cmap = plt.cm.Reds)
#      26
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map_lower(self, func, **kwargs)
#    1355         """
#    1356         indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1357         self._map_bivariate(func, indices, **kwargs)
#    1358         return self
#    1359
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in _map_bivariate(self, func, indices, **kwargs)
#    1537             if ax is None:  # i.e. we are in corner mode
#    1538                 continue
# -> 1539             self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1540         self._add_axis_labels()
#    1541
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in _plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1546         """Draw a bivariate plot on the specified axes."""
#    1547         if "hue" not in signature(func).parameters:
# -> 1548             self._plot_bivariate_iter_hue(x_var, y_var, ax, func, **kwargs)
#    1549             return
#    1550
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in _plot_bivariate_iter_hue(self, x_var, y_var, ax, func, **kwargs)
#    1621                 func(x=x, y=y, **kws)
#    1622             else:
# -> 1623                 func(x, y, **kws)
#    1624
#    1625         self._update_legend_data(ax)
#
# <ipython-input-31-3a1809577e82> in corr_func(x, y, **kwargs)
#       6 # Function to calculate correlation coefficient between two columns
#       7 def corr_func(x, y, **kwargs):
# ----> 8     r = np.corrcoef(x, y)[2][4][5]
#       9     ax = plt.gca()
#      10     ax.annotate("r = {:.2f}".format(r),
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
# Putting feature variable to X
X = dataset.iloc[ : ,[2,4,5]]
# Putting response variable to y
y = dataset.iloc[:,[6]]
y.shape,X.shape
# Out:
# ((92876, 1), (92876, 3))

# %%
# now lets split the data into train and test
from sklearn.model_selection import train_test_split
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((65013, 3), (27863, 3))

# %%
# Fitting Random Forest Regression to the dataset
# import the regressor
from sklearn.ensemble import RandomForestRegressor
 
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
# fit the regressor with x and y data
regressor.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred.shape,y_test.shape
# Out:
# ((27863,), (27863, 1))

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 175.2962707118955
# Mean Squared Error: 531471.223779725
# Root Mean Squared Error: 729.0207293210016

# %% [markdown]
# Here, we can see that Random Forest Regressor Algorithm is not giving required insights.

# %%
#Fitting Decissiopn Regression
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state=0)
#Fit the regressor object to the dataset.
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 191.035344187997
# Mean Squared Error: 727315.4806447892
# Root Mean Squared Error: 852.8279314403283

# %%
import lightgbm as lgb
# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

print('Starting training...')
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=20,
                valid_sets=lgb_eval,
                callbacks=[lgb.early_stopping(stopping_rounds=5)])

print('Saving model...')
# save model to file
gbm.save_model('model.txt')

print('Starting predicting...')
# predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Starting training...
# [1]	valid_0's l1: 176.365	valid_0's l2: 486757
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's l1: 175.222	valid_0's l2: 485538
# [3]	valid_0's l1: 174.207	valid_0's l2: 484449
# [4]	valid_0's l1: 173.278	valid_0's l2: 483398
# [5]	valid_0's l1: 172.454	valid_0's l2: 482503
# [6]	valid_0's l1: 172.461	valid_0's l2: 482532
# [7]	valid_0's l1: 171.712	valid_0's l2: 481712
# [8]	valid_0's l1: 171.015	valid_0's l2: 480968
# [9]	valid_0's l1: 170.381	valid_0's l2: 480290
# [10]	valid_0's l1: 170.385	valid_0's l2: 480324
# [11]	valid_0's l1: 170.32	valid_0's l2: 480340
# [12]	valid_0's l1: 170.295	valid_0's l2: 480370
# [13]	valid_0's l1: 170.269	valid_0's l2: 480395
# [14]	valid_0's l1: 169.676	valid_0's l2: 479778
# [15]	valid_0's l1: 169.658	valid_0's l2: 479800
# [16]	valid_0's l1: 169.136	valid_0's l2: 479276
# [17]	valid_0's l1: 168.632	valid_0's l2: 478762
# [18]	valid_0's l1: 168.2	valid_0's l2: 478324
# [19]	valid_0's l1: 167.772	valid_0's l2: 477896
# [20]	valid_0's l1: 167.404	valid_0's l2: 477507
# Did not meet early stopping. Best iteration is:
# [20]	valid_0's l1: 167.404	valid_0's l2: 477507
# Saving model...
# Starting predicting...
# Mean Absolute Error: 167.40361413347628
# Mean Squared Error: 477507.29482724704
# Root Mean Squared Error: 691.0190263858493
